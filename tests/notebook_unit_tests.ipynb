# %% [markdown]
# ## text/plain

# %%
"Hello, this is plain text output"
# Out:
# 'Hello, this is plain text output'

# %% [markdown]
# # text/latex

# %%
from IPython.display import display, Latex
display(Latex(r'$\int x^2 dx = \frac{x^3}{3} + C$'))
# Out:
# $\int x^2 dx = \frac{x^3}{3} + C$

# %% [markdown]
# ## text/html

# %%
from IPython.display import display, HTML
display(HTML('<table><tr><td style="color:red">HTML Table Cell</td></tr></table>'))
# Out:
# <table><tr><td style="color:red">HTML Table Cell</td></tr></table>

# %% [markdown]
# ## text/markdown

# %%
from IPython.display import display, Markdown
display(Markdown('**Bold** and *italic* markdown'))
# Out:
# **Bold** and *italic* markdown

# %% [markdown]
# ## application/json

# %%
from IPython.display import display, JSON
display(JSON({'key': 'value', 'numbers': [1, 2, 3]}))

# %% [markdown]
# ## stream text

# %%
print("This is stdout stream output")
# Out:
# This is stdout stream output

# %% [markdown]
# ##stream error

# %%
import sys
sys.stderr.write("This is stderr stream output\n")
# Out:
# This is stderr stream output
# 29

# %% [markdown]
# ## error

# %%
raise ValueError("This is an intentional error for testing")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2550326204.py in <cell line: 0>()
# ----> 1 raise ValueError("This is an intentional error for testing")
#
# ValueError: This is an intentional error for testing

# %% [markdown]
# ## pandas

# %%
import pandas as pd
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %% [markdown]
# ## javascript (unprocessable)

# %%
from IPython.display import Javascript
display(Javascript('console.log("test")'))

# %% [markdown]
# ## widget

# %%
import ipywidgets as widgets
widgets.IntSlider(value=50, min=0, max=100)
# Out:
# IntSlider(value=50)

# %% [markdown]
# ## image

# %%
from PIL import Image
img = Image.new('RGB', (16, 16), color='blue')
img
# Out:
# <PIL.Image.Image image mode=RGB size=16x16>

# %% [markdown]
# ## Markdown Image
# image.png

# %% [markdown]
# ## Print the Cells as a Dict

# %%
from google.colab import _message, userdata
notebook_json = _message.blocking_request('get_ipynb')
notebook_json['ipynb']['cells']
# Out:
# [{'cell_type': 'markdown',
#   'source': ['## text/plain'],
#   'metadata': {'id': 'rtKwpV6U0Bzc'}},
#  {'cell_type': 'code',
#   'source': ['"Hello, this is plain text output"\n'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 36},
#    'id': 'kOlrMj0y0Ckm',
#    'executionInfo': {'status': 'ok',
#     'timestamp': 1764741963567,
#     'user_tz': -120,
#     'elapsed': 14,
#     'user': {'displayName': 'neural vfx', 'userId': '03490278602357893511'}},
#    'outputId': 'e103f6fd-0d18-4467-e996-28e084b0b61b'},
#   'execution_count': 1,
#   'outputs': [{'output_type': 'execute_result',
#     'data': {'text/plain': ["'Hello, this is plain text output'"],
#      'application/vnd.google.colaboratory.intrinsic+json': {'type': 'string'}},
#     'metadata': {},
#     'execution_count': 1}]},
#  {'cell_type': 'markdown',
#   'source': ['# text/latex'],
#   'metadata': {'id': 'NybCn2ZG0KTJ'}},
#  {'cell_type': 'code',
# ...

# %%
# !pip install lisette

# %%
# !git clone https://github.com/NeuralVFX/colab-ask
# %cd colab-ask
# %load_ext colab-ask

# %%
# %set_model gpt-5.1
# Out:
# Model set to: gpt-5.1

# %%
# %%ask
# please sumarize a punch by punch description of this notebook
# Out:
# <p>Here’s a punch‑by‑punch walkthrough of what this notebook is doing, in order:</p>
# <ol>
# <li><p><strong>text/plain demo</strong></p>
# <ul>
# <li>Markdown: <code>## text/plain</code></li>
# <li>Code: <code>&quot;Hello, this is plain text output&quot;</code></li>
# <li>Output: A string result (<code>'Hello, this is plain text output'</code>) with intrinsic JSON metadata saying it’s a <code>&quot;string&quot;</code>.</li>
# <li>Purpose: Show a simple expression result and its <code>text/plain</code> representation.</li>
# </ul>
# </li>
# <li><p><strong>LaTeX demo (text/latex)</strong></p>
# <ul>
# <li>Markdown: <code># text/latex</code></li>
# <li>Code:<pre><code class="language-python">from IPython.display import display, Latex
# display(Latex(r'$\int x^2 dx = \frac{x^3}{3} + C$'))
# </code></pre>
# </li>
# <li>Output: A LaTeX object rendered as math and represented as both <code>text/plain</code> and <code>text/latex</code>.</li>
# ...
